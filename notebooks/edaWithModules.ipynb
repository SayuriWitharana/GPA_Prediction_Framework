# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)

# %%
DATA_PATH = Path("../data/raw/DatasetWithModules_Training.xlsx")
df = pd.read_excel(DATA_PATH)

# %%
grade_map = {
    'A+': 11, 'A': 10, 'A-': 9, 'B+': 8, 'B': 7, 
    'B-': 6, 'C+': 5, 'C': 4, 'C-': 3, 'S': 2, 'F': 1
}

module_columns = ['Maths 2', 'MgtAccounting', 'StatsII', 'MIS', 'DataV'] # List your Semester X modules here

for col in module_columns:
    # We use .strip() in case there are hidden spaces like "A "
    df[col] = df[col].astype(str).str.strip().map(grade_map)
    df[col] = df[col].fillna(0)


def assign_perf_group(gpa):
    if gpa <= 2.99:
        return "Underperforming"
    elif gpa <= 3.29:
        return "Average"
    else:
        return "Performing"

df["GroupLabel"] = df["FinalGPA"].apply(assign_perf_group)

# %%
print("Shape:", df.shape)
print("Data types:\n", df.dtypes)
# Out:
# Shape: (270, 24)
# Data types:
#  Year               int64
# Index No.            str
# FinalGPA         float64
# S1               float64
# S2               float64
# S3               float64
# S4               float64
# S5               float64
# S6               float64
# S7               float64
# S8               float64
# Department           str
# Zscore           float64
# Gender               str
# EnglishMarks     float64
# District             str
# Province             str
# MediumAL             str
# Maths 2            int64
# MgtAccounting      int64
# StatsII            int64
# MIS                int64
# DataV              int64
# GroupLabel           str
# dtype: object

# %%
df.head()
# Out:
#    Year Index No.  FinalGPA    S1    S2    S3    S4    S5    S6    S7    S8 Department  Zscore Gender  EnglishMarks      District       Province MediumAL  Maths 2  MgtAccounting  StatsII  MIS  \
# 0  2017   176096J      3.88  2.30  1.76  2.24  2.45  2.82  2.44  0.00  0.00         BA  1.8487      F          66.0       Badulla            Uva        S       11              7       10    4
# 1  2017   176095F      3.67  2.41  1.46  2.47  1.54  1.40  1.41  2.65  3.03         BA  1.5718      M          82.0  Anuradhapura  North Central        E        5              8        6    7
# 2  2017   176094C      2.74  1.79  1.91  1.74  1.97  1.91  2.63  1.52  2.50        FSM  1.6005      M           NaN       Colombo        Western        S       11              4        9   11
# 3  2017   176093X      3.36  2.27  2.34  2.07  2.23  2.05  2.84  2.25  2.35        BPM  1.7060      F          92.0     Ratnapura   Sabaragamuwa        S       10              6        4    5
# 4  2017   176092T      3.83  2.15  2.49  2.01  2.69  2.43  2.91  2.45  2.46         BA  1.5602      F          76.0      Kalutara        Western        S       11              7       10   11
#
#    DataV       GroupLabel
# 0     10       Performing
# 1     11       Performing
# 2     10  Underperforming
# 3     11       Performing
# 4     10       Performing

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           270 non-null    int64
#  1   Index No.      270 non-null    str
#  2   FinalGPA       270 non-null    float64
#  3   S1             270 non-null    float64
#  4   S2             270 non-null    float64
#  5   S3             270 non-null    float64
#  6   S4             270 non-null    float64
#  7   S5             270 non-null    float64
#  8   S6             270 non-null    float64
#  9   S7             270 non-null    float64
#  10  S8             270 non-null    float64
#  11  Department     270 non-null    str
#  12  Zscore         270 non-null    float64
#  13  Gender         270 non-null    str
#  14  EnglishMarks   263 non-null    float64
#  15  District       270 non-null    str
#  16  Province       270 non-null    str
#  17  MediumAL       270 non-null    str
#  18  Maths 2        270 non-null    int64
#  19  MgtAccounting  270 non-null    int64
#  20  StatsII        270 non-null    int64
#  21  MIS            270 non-null    int64
#  22  DataV          270 non-null    int64
#  23  GroupLabel     270 non-null    str
# dtypes: float64(11), int64(6), str(7)
# memory usage: 60.7 KB

# %%
print(df[['Maths 2', 'MgtAccounting', 'StatsII', 'MIS', 'DataV']].describe())
# Out:
#           Maths 2  MgtAccounting     StatsII         MIS       DataV
# count  270.000000     270.000000  270.000000  270.000000  270.000000
# mean     7.370370       7.644444    6.922222    8.303704    9.851852
# std      2.928493       2.261580    2.718084    2.190802    1.515808
# min      1.000000       2.000000    1.000000    2.000000    2.000000
# 25%      4.000000       6.000000    5.000000    7.000000   10.000000
# 50%      8.000000       8.000000    7.000000    9.000000   10.000000
# 75%     10.000000      10.000000   10.000000   10.000000   11.000000
# max     11.000000      11.000000   11.000000   11.000000   11.000000
